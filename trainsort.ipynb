# %%
#!git clone https://github.com/ZQPei/deep_sort_pytorch.git
# Out:
# Cloning into 'deep_sort_pytorch'...
# remote: Enumerating objects: 726, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 726 (delta 4), reused 1 (delta 0), pack-reused 717
# Receiving objects: 100% (726/726), 23.72 MiB | 9.73 MiB/s, done.
# Resolving deltas: 100% (351/351), done.

# %%
# !git clone https://github.com/heejae1213/object_tracking_deepsort.git
# Out:
# Cloning into 'object_tracking_deepsort'...
# remote: Enumerating objects: 216, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 216 (delta 16), reused 7 (delta 2), pack-reused 184
# Receiving objects: 100% (216/216), 83.64 MiB | 29.66 MiB/s, done.
# Resolving deltas: 100% (62/62), done.

# %%
# %cd /content/object_tracking_deepsort/feature extractor
# Out:
# /content/object_tracking_deepsort/feature extractor

# %%
# !git clone -b main2 https://github.com/wadi-sudo/deepdrone.git
# Out:
# Cloning into 'deepdrone'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 7 (delta 0), reused 4 (delta 0), pack-reused 0
# Unpacking objects: 100% (7/7), 961 bytes | 961.00 KiB/s, done.

# %%
# !pip install comet-ml

# %%
# %cd deepdrone
# !unzip data.zip

# %%
# %cd ..
# Out:
# /content/object_tracking_deepsort/feature extractor

# %%
from comet_ml import Experiment
experiment = Experiment(api_key="imqh6zu2LxG3M5OKWP4zmeQbs", project_name="yolov8train", workspace="cryptdata", auto_metric_logging=True, auto_param_logging=True, auto_histogram_weight_logging=True, auto_histogram_gradient_logging=True, auto_histogram_activation_logging=True)

# !python siamese_train.py
experiment.end()

# %%
# !python siamese_test.py
